# %%
import requests 
import json 
from bs4 import BeautifulSoup 


r = requests.get("https://www.instagram.com/fredwilson/?hl=en") 
soup = BeautifulSoup(r.content, 'html.parser') 
script = soup.find_all('script')[6].string
script_data = json.loads(script[21:-1]) 
user_data = script_data["entry_data"]["ProfilePage"][0]["user"]
list(user_data)
# Out:
# [u'username',
#  u'country_block',
#  u'connected_fb_page',
#  u'follows',
#  u'requested_by_viewer',
#  u'followed_by',
#  u'external_url_linkshimmed',
#  u'has_requested_viewer',
#  u'blocked_by_viewer',
#  u'follows_viewer',
#  u'profile_pic_url_hd',
#  u'profile_pic_url',
#  u'is_private',
#  u'full_name',
#  u'media',
#  u'has_blocked_viewer',
#  u'followed_by_viewer',
#  u'is_verified',
#  u'id',
#  u'biography',
#  u'external_url']

# %%
instagram = {"username":[], 'posts':[], 'followed_by':[],'is_private':[],'full_name':[], 'follows':[]}

List = ("https://www.instagram.com/sacca/?hl=en",
        "https://www.instagram.com/jim.goetz/",
        "https://www.instagram.com/jimihendrixlive/",
       "https://www.instagram.com/mattcohler/",
       "https://www.instagram.com/bijan/?hl=en",
       "https://www.instagram.com/toddchaffee/?hl=en",
       "https://www.instagram.com/sa1i1/",
        "https://www.instagram.com/jeremysliew/",
        "https://www.instagram.com/jdoerr/",
        "https://www.instagram.com/neilr/",
        "https://www.instagram.com/satishd/"
       )

def instagram_data(): 
    for vc in List:
        r = requests.get(vc)
        soup = BeautifulSoup(r.content, 'html.parser')
        script = soup.find_all('script')[6].string
        script_data = json.loads(script[21:-1]) 
        user_data = script_data["entry_data"]["ProfilePage"][0]["user"]
        for x in user_data:
            if x == 'full_name':
                instagram['full_name'].append(user_data[x])
            elif x == 'media':
                instagram['posts'].append((user_data[x]['count']))
            elif  x == "username":
                instagram['username'].append(user_data[x])
            elif x == "follows" :
                instagram['follows'].append((user_data[x]['count']))
            elif x == "followed_by":
                instagram['followed_by'].append((user_data[x]['count'] ))
            elif x == "is_private":
                instagram["is_private"].append(user_data[x])
        print instagram

    
instagram_data()
# Out:
# {'username': [u'sacca'], 'follows': [248], 'followed_by': [38121], 'posts': [310], 'full_name': [u'Chris Sacca'], 'is_private': [False]}
# {'username': [u'sacca', u'jim.goetz'], 'follows': [248, 1505], 'followed_by': [38121, 223], 'posts': [310, 12], 'full_name': [u'Chris Sacca', u'Jim Goetz'], 'is_private': [False, False]}
# {'username': [u'sacca', u'jim.goetz', u'jimihendrixlive'], 'follows': [248, 1505, 1480], 'followed_by': [38121, 223, 546], 'posts': [310, 12, 182], 'full_name': [u'Chris Sacca', u'Jim Goetz', u'Jim Breyer'], 'is_private': [False, False, True]}
# {'username': [u'sacca', u'jim.goetz', u'jimihendrixlive', u'mattcohler'], 'follows': [248, 1505, 1480, 220], 'followed_by': [38121, 223, 546, 2303], 'posts': [310, 12, 182, 128], 'full_name': [u'Chris Sacca', u'Jim Goetz', u'Jim Breyer', u'Matt Cohler'], 'is_private': [False, False, True, True]}
# {'username': [u'sacca', u'jim.goetz', u'jimihendrixlive', u'mattcohler', u'bijan'], 'follows': [248, 1505, 1480, 220, 251], 'followed_by': [38121, 223, 546, 2303, 8988], 'posts': [310, 12, 182, 128, 634], 'full_name': [u'Chris Sacca', u'Jim Goetz', u'Jim Breyer', u'Matt Cohler', u'Bijan Sabet'], 'is_private': [False, False, True, True, False]}
# {'username': [u'sacca', u'jim.goetz', u'jimihendrixlive', u'mattcohler', u'bijan', u'toddchaffee'], 'follows': [248, 1505, 1480, 220, 251, 485], 'followed_by': [38121, 223, 546, 2303, 8988, 15391], 'posts': [310, 12, 182, 128, 634, 782], 'full_name': [u'Chris Sacca', u'Jim Goetz', u'Jim Breyer', u'Matt Cohler', u'Bijan Sabet', u'Todd Chaffee'], 'is_private': [False, False, True, True, False, False]}
# {'username': [u'sacca', u'jim.goetz', u'jimihendrixlive', u'mattcohler', u'bijan', u'toddchaffee', u'sa1i1'], 'follows': [248, 1505, 1480, 220, 251, 485, 244], 'followed_by': [38121, 223, 546, 2303, 8988, 15391, 240], 'posts': [310, 12, 182, 128, 634, 782, 160], 'full_name': [u'Chris Sacca', u'Jim Goetz', u'Jim Breyer', u'Matt Cohler', u'Bijan Sabet', u'Todd Chaffee', u'Salil Deshpande'], 'is_private': [False, False, True, True, False, False, False]}
# {'username': [u'sacca', u'jim.goetz', u'jimihendrixlive', u'mattcohler', u'bijan', u'toddchaffee', u'sa1i1', u'jeremysliew'], 'follows': [248, 1505, 1480, 220, 251, 485, 244, 705], 'followed_by': [38121, 223, 546, 2303, 8988, 15391, 240, 423], 'posts': [310, 12, 182, 128, 634, 782, 160, 7], 'full_name': [u'Chris Sacca', u'Jim Goetz', u'Jim Breyer', u'Matt Cohler', u'Bijan Sabet', u'Todd Chaffee', u'Salil Deshpande', u'Jeremy Liew'], 'is_private': [False, False, True, True, False, False, False, False]}
# {'username': [u'sacca', u'jim.goetz', u'jimihendrixlive', u'mattcohler', u'bijan', u'toddchaffee', u'sa1i1', u'jeremysliew', u'jdoerr'], 'follows': [248, 1505, 1480, 220, 251, 485, 244, 705, 54], 'followed_by': [38121, 223, 546, 2303, 8988, 15391, 240, 423, 300], 'posts': [310, 12, 182, 128, 634, 782, 160, 7, 73], 'full_name': [u'Chris Sacca', u'Jim Goetz', u'Jim Breyer', u'Matt Cohler', u'Bijan Sabet', u'Todd Chaffee', u'Salil Deshpande', u'Jeremy Liew', u'John Doerr'], 'is_private': [False, False, True, True, False, False, False, False, True]}
# {'username': [u'sacca', u'jim.goetz', u'jimihendrixlive', u'mattcohler', u'bijan', u'toddchaffee', u'sa1i1', u'jeremysliew', u'jdoerr', u'neilr'], 'follows': [248, 1505, 1480, 220, 251, 485, 244, 705, 54, 30], 'followed_by': [38121, 223, 546, 2303, 8988, 15391, 240, 423, 300, 132], 'posts': [310, 12, 182, 128, 634, 782, 160, 7, 73, 5], 'full_name': [u'Chris Sacca', u'Jim Goetz', u'Jim Breyer', u'Matt Cohler', u'Bijan Sabet', u'Todd Chaffee', u'Salil Deshpande', u'Jeremy Liew', u'John Doerr', u'Neil Rimer'], 'is_private': [False, False, True, True, False, False, False, False, True, True]}
# {'username': [u'sacca', u'jim.goetz', u'jimihendrixlive', u'mattcohler', u'bijan', u'toddchaffee', u'sa1i1', u'jeremysliew', u'jdoerr', u'neilr', u'satishd'], 'follows': [248, 1505, 1480, 220, 251, 485, 244, 705, 54, 30, 60], 'followed_by': [38121, 223, 546, 2303, 8988, 15391, 240, 423, 300, 132, 251], 'posts': [310, 12, 182, 128, 634, 782, 160, 7, 73, 5, 23], 'full_name': [u'Chris Sacca', u'Jim Goetz', u'Jim Breyer', u'Matt Cohler', u'Bijan Sabet', u'Todd Chaffee', u'Salil Deshpande', u'Jeremy Liew', u'John Doerr', u'Neil Rimer', u'Satish Dharmaraj'], 'is_private': [False, False, True, True, False, False, False, False, True, True, False]}

# %%
import pandas as pd
final = pd.DataFrame(instagram)
final
# Out:
#     followed_by  follows         full_name is_private  posts         username
# 0         38121      248       Chris Sacca      False    310            sacca
# 1           223     1505         Jim Goetz      False     12        jim.goetz
# 2           546     1480        Jim Breyer       True    182  jimihendrixlive
# 3          2303      220       Matt Cohler       True    128       mattcohler
# 4          8988      251       Bijan Sabet      False    634            bijan
# 5         15391      485      Todd Chaffee      False    782      toddchaffee
# 6           240      244   Salil Deshpande      False    160            sa1i1
# 7           423      705       Jeremy Liew      False      7      jeremysliew
# 8           300       54        John Doerr       True     73           jdoerr
# 9           132       30        Neil Rimer       True      5            neilr
# 10          251       60  Satish Dharmaraj      False     23          satishd
